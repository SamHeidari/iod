# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
df = pd.read_csv("../../Data Folder/Employee-attrition.csv")

# %%
df
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# 1                1/1/1900   53                 18    Vancouver
# 2                1/1/1900   54                 19    Vancouver
# 3                1/1/1900   55                 20    Vancouver
# 4                1/1/1900   56                 21    Vancouver
# ...                   ...  ...                ...          ...
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 0             Executive           CEO          35            M        Male
# 1             Executive           CEO          35            M        Male
# 2             Executive           CEO          35            M        Male
# 3             Executive           CEO          35            M        Male
# 4             Executive           CEO          35            M        Male
# ...                 ...           ...         ...          ...         ...
# 49648             Dairy  Dairy Person          34            M        Male
# 49649  Customer Service       Cashier          44            F      Female
# 49650  Customer Service       Cashier          39            F      Female
# 49651  Customer Service       Cashier          16            F      Female
# 49652  Customer Service       Cashier          13            F      Female
#
#       termreason_desc   termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 0      Not Applicable  Not Applicable         2006      ACTIVE    HEADOFFICE
# 1      Not Applicable  Not Applicable         2007      ACTIVE    HEADOFFICE
# 2      Not Applicable  Not Applicable         2008      ACTIVE    HEADOFFICE
# 3      Not Applicable  Not Applicable         2009      ACTIVE    HEADOFFICE
# 4      Not Applicable  Not Applicable         2010      ACTIVE    HEADOFFICE
# ...               ...             ...          ...         ...           ...
# 49648          Layoff     Involuntary         2015  TERMINATED        STORES
# 49649      Resignaton       Voluntary         2013  TERMINATED        STORES
# 49650          Layoff     Involuntary         2015  TERMINATED        STORES
# 49651      Resignaton       Voluntary         2013  TERMINATED        STORES
# 49652          Layoff     Involuntary         2014  TERMINATED        STORES
#
# [49653 rows x 18 columns]

# %%
df.head(10)
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6        1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7        1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8        1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9        1318  12/31/2015 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
# 5            1/1/1900   57                 22  Vancouver       Executive
# 6            1/1/1900   58                 23  Vancouver       Executive
# 7            1/1/1900   59                 24  Vancouver       Executive
# 8            1/1/1900   60                 25  Vancouver       Executive
# 9            1/1/1900   61                 26  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
# 3       CEO          35            M        Male  Not Applicable
# 4       CEO          35            M        Male  Not Applicable
# 5       CEO          35            M        Male  Not Applicable
# 6       CEO          35            M        Male  Not Applicable
# 7       CEO          35            M        Male  Not Applicable
# 8       CEO          35            M        Male  Not Applicable
# 9       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1  Not Applicable         2007  ACTIVE    HEADOFFICE
# 2  Not Applicable         2008  ACTIVE    HEADOFFICE
# 3  Not Applicable         2009  ACTIVE    HEADOFFICE
# 4  Not Applicable         2010  ACTIVE    HEADOFFICE
# 5  Not Applicable         2011  ACTIVE    HEADOFFICE
# 6  Not Applicable         2012  ACTIVE    HEADOFFICE
# 7  Not Applicable         2013  ACTIVE    HEADOFFICE
# 8  Not Applicable         2014  ACTIVE    HEADOFFICE
# 9  Not Applicable         2015  ACTIVE    HEADOFFICE

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# 49649  Customer Service       Cashier          44            F      Female
# 49650  Customer Service       Cashier          39            F      Female
# 49651  Customer Service       Cashier          16            F      Female
# 49652  Customer Service       Cashier          13            F      Female
#
#       termreason_desc termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 49648          Layoff   Involuntary         2015  TERMINATED        STORES
# 49649      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49650          Layoff   Involuntary         2015  TERMINATED        STORES
# 49651      Resignaton     Voluntary         2013  TERMINATED        STORES
# 49652          Layoff   Involuntary         2014  TERMINATED        STORES

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=49653, step=1)

# %%
data
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %%
df.values[12]
# Out:
# array([1319, '12/31/2008 0:00', '1/3/1957', '8/28/1989', '1/1/1900', 51,
#        19, 'Vancouver', 'Executive', 'VP Stores', 35, 'F', 'Female',
#        'Not Applicable', 'Not Applicable', 2008, 'ACTIVE', 'HEADOFFICE'],
#       dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find the shape of the dataframe

# %%
# A:
df.shape[0]
# Out:
# 18

# %%
print(f'this raw data has {df.shape[0]}rows,and {df.shape[1]}columns')
# Out:
# this raw data has 49653rows,and 18columns

# %% [markdown]
# #### 1.B Find the data types of the dataframe

# %%
# A:
df.dtypes
# Out:
# EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object

# %%
df[['age','job_title']]
# Out:
#        age     job_title
# 0       52           CEO
# 1       53           CEO
# 2       54           CEO
# 3       55           CEO
# 4       56           CEO
# ...    ...           ...
# 49648   21  Dairy Person
# 49649   19       Cashier
# 49650   21       Cashier
# 49651   19       Cashier
# 49652   20       Cashier
#
# [49653 rows x 2 columns]

# %%
df.age.mean()
# Out:
# 42.077034620264634

# %%
df[(df['job_title'] == 'CEO')& (df['city_name']=='Vancouver')]
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6        1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7        1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8        1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9        1318  12/31/2015 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
# 5            1/1/1900   57                 22  Vancouver       Executive
# 6            1/1/1900   58                 23  Vancouver       Executive
# 7            1/1/1900   59                 24  Vancouver       Executive
# 8            1/1/1900   60                 25  Vancouver       Executive
# 9            1/1/1900   61                 26  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
# 3       CEO          35            M        Male  Not Applicable
# 4       CEO          35            M        Male  Not Applicable
# 5       CEO          35            M        Male  Not Applicable
# 6       CEO          35            M        Male  Not Applicable
# 7       CEO          35            M        Male  Not Applicable
# 8       CEO          35            M        Male  Not Applicable
# 9       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1  Not Applicable         2007  ACTIVE    HEADOFFICE
# 2  Not Applicable         2008  ACTIVE    HEADOFFICE
# 3  Not Applicable         2009  ACTIVE    HEADOFFICE
# 4  Not Applicable         2010  ACTIVE    HEADOFFICE
# 5  Not Applicable         2011  ACTIVE    HEADOFFICE
# 6  Not Applicable         2012  ACTIVE    HEADOFFICE
# 7  Not Applicable         2013  ACTIVE    HEADOFFICE
# 8  Not Applicable         2014  ACTIVE    HEADOFFICE
# 9  Not Applicable         2015  ACTIVE    HEADOFFICE

# %% [markdown]
# #### 1.C Find the number of data types in the dataframe
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %%
df.dtypes.value_counts()
# Out:
# object    13
# int64      5
# Name: count, dtype: int64

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore the difference.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  object
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  object
#  4   terminationdate_key  49653 non-null  object
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
#  15  STATUS_YEAR          49653 non-null  int64
#  16  STATUS               49653 non-null  object
#  17  BUSINESS_UNIT        49653 non-null  object
# dtypes: int64(5), object(13)
# memory usage: 6.8+ MB

# %%
#adding a new column to data Frame
df['name'] = np.nan

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %%
df.city_name
# Out:
# 0          Vancouver
# 1          Vancouver
# 2          Vancouver
# 3          Vancouver
# 4          Vancouver
#             ...
# 49648      Valemount
# 49649      Vancouver
# 49650     White Rock
# 49651        Kelowna
# 49652    Grand Forks
# Name: city_name, Length: 49653, dtype: object

# %%
df["city_name"].value_counts().tail()
# Out:
# city_name
# Pitt Meadows     57
# Cortes Island    43
# Valemount        37
# Dease Lake       18
# Blue River        9
# Name: count, dtype: int64

# %% [markdown]
# #### 2.A Check Values of the `job_title` column

# %% [markdown]
# #### 2.B Find how many rows are in each job title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
df.job_title.value_counts()
# Out:
# job_title
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Bakery Manager                      285
# Meats Manager                       285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Labor Relations Analyst              30
# Accounts Receiveable Clerk           30
# Trainer                              26
# Accounts Payable Clerk               25
# Auditor                              20
# Systems Analyst                      20
# Investment Analyst                   20
# Compensation Analyst                 20
# Corporate Lawyer                     17
# CEO                                  10
# Exec Assistant, VP Stores            10
# Legal Counsel                        10
# VP Stores                            10
# VP Human Resources                   10
# VP Finance                           10
# Director, Recruitment                10
# Exec Assistant, Finance              10
# Exec Assistant, Human Resources      10
# CHief Information Officer            10
# Exec Assistant, Legal Counsel        10
# Director, Accounts Payable            9
# Director, Accounts Receivable         9
# Director, Employee Records            9
# Director, HR Technology               9
# Dairy Manager                         9
# Director, Accounting                  9
# Director, Investments                 4
# Director, Labor Relations             4
# Director, Compensation                4
# Director, Audit                       4
# Director, Training                    4
# Name: count, dtype: int64

# %%
df['age'].value_counts()
# Out:
# age
# 27    1235
# 29    1227
# 28    1225
# 50    1218
# 30    1212
# 26    1210
# 51    1207
# 25    1197
# 49    1196
# 35    1189
# 34    1188
# 53    1188
# 52    1188
# 48    1180
# 36    1176
# 47    1173
# 55    1168
# 33    1164
# 46    1161
# 54    1159
# 44    1157
# 38    1156
# 56    1154
# 32    1153
# 42    1152
# 43    1150
# 37    1149
# 31    1146
# 39    1142
# 45    1141
# 41    1135
# 58    1130
# 57    1130
# 40    1130
# 59    1128
# 24    1111
# 60    1109
# 23     960
# 22     815
# 61     757
# 62     712
# 21     703
# 63     667
# 64     646
# 65     593
# 20     408
# 19     158
# Name: count, dtype: int64

# %% [markdown]
# #### 2.C [BONUS] Write a function to count the number of rows
#
#
# ```
# def row_count(column_name):
#     number_of_rows = 0
#     return number_of_rows
# ```

# %%
df.describe(include='all').T
# Out:
#                        count unique              top   freq         mean  \
# EmployeeID           49653.0    NaN              NaN    NaN   4859.49574
# recorddate_key         49653    130  12/31/2013 0:00   5215          NaN
# birthdate_key          49653   5342        3/23/1973     40          NaN
# orighiredate_key       49653   4415        9/25/2006     50          NaN
# terminationdate_key    49653   1055         1/1/1900  42450          NaN
# age                  49653.0    NaN              NaN    NaN    42.077035
# length_of_service    49653.0    NaN              NaN    NaN    10.434596
# city_name              49653     40        Vancouver  11211          NaN
# department_name        49653     21            Meats  10269          NaN
# job_title              49653     47      Meat Cutter   9984          NaN
# store_name           49653.0    NaN              NaN    NaN    27.297605
# gender_short           49653      2                F  25898          NaN
# gender_full            49653      2           Female  25898          NaN
# termreason_desc        49653      4   Not Applicable  48168          NaN
# termtype_desc          49653      3   Not Applicable  48168          NaN
# STATUS_YEAR          49653.0    NaN              NaN    NaN  2010.612612
# STATUS                 49653      2           ACTIVE  48168          NaN
# BUSINESS_UNIT          49653      2           STORES  49068          NaN
#
#                              std     min     25%     50%     75%     max
# EmployeeID           1826.571142  1318.0  3360.0  5031.0  6335.0  8336.0
# recorddate_key               NaN     NaN     NaN     NaN     NaN     NaN
# birthdate_key                NaN     NaN     NaN     NaN     NaN     NaN
# orighiredate_key             NaN     NaN     NaN     NaN     NaN     NaN
# terminationdate_key          NaN     NaN     NaN     NaN     NaN     NaN
# age                    12.427257    19.0    31.0    42.0    53.0    65.0
# length_of_service       6.325286     0.0     5.0    10.0    15.0    26.0
# city_name                    NaN     NaN     NaN     NaN     NaN     NaN
# department_name              NaN     NaN     NaN     NaN     NaN     NaN
# job_title                    NaN     NaN     NaN     NaN     NaN     NaN
# store_name             13.514134     1.0    16.0    28.0    42.0    46.0
# gender_short                 NaN     NaN     NaN     NaN     NaN     NaN
# gender_full                  NaN     NaN     NaN     NaN     NaN     NaN
# termreason_desc              NaN     NaN     NaN     NaN     NaN     NaN
# termtype_desc                NaN     NaN     NaN     NaN     NaN     NaN
# STATUS_YEAR             2.845577  2006.0  2008.0  2011.0  2013.0  2015.0
# STATUS                       NaN     NaN     NaN     NaN     NaN     NaN
# BUSINESS_UNIT                NaN     NaN     NaN     NaN     NaN     NaN

# %% [markdown]
# #### 2.D Describe `age`
#
# Find the count, mean, std, min, max of the column 'age'

# %%
# A:
df["age"].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ##### 2.E [BONUS] Describe all numeric columns of the dataframe
#
# Find the count, mean, std, min, max of all columns of the dataframe

# %%
# A:
df.select_dtypes(include = np.number).describe()
# Out:
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# 75%     2013.000000
# max     2015.000000

# %% [markdown]
# # 3. Make the index meaningful by making `EmployeeID` the index

# %%
df.set_index('EmployeeID',inplace = True)

# %% [markdown]
# #### 3.A Find a specific row using the index

# %%
df.loc[1700]
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1700        12/31/2006 0:00      1/2/1951        9/18/1990
# 1700        12/31/2007 0:00      1/2/1951        9/18/1990
# 1700        12/31/2008 0:00      1/2/1951        9/18/1990
# 1700        12/31/2009 0:00      1/2/1951        9/18/1990
# 1700        12/31/2010 0:00      1/2/1951        9/18/1990
# 1700        12/31/2011 0:00      1/2/1951        9/18/1990
# 1700        12/31/2012 0:00      1/2/1951        9/18/1990
# 1700        12/31/2013 0:00      1/2/1951        9/18/1990
# 1700        12/31/2014 0:00      1/2/1951        9/18/1990
# 1700         12/1/2015 0:00      1/2/1951        9/18/1990
#
#            terminationdate_key  age  length_of_service city_name  \
# EmployeeID
# 1700                12/30/2015   55                 16  Victoria
# 1700                12/30/2015   56                 17  Victoria
# 1700                12/30/2015   57                 18  Victoria
# 1700                12/30/2015   58                 19  Victoria
# 1700                12/30/2015   59                 20  Victoria
# 1700                12/30/2015   60                 21  Victoria
# 1700                12/30/2015   61                 22  Victoria
# 1700                12/30/2015   62                 23  Victoria
# 1700                12/30/2015   63                 24  Victoria
# 1700                12/30/2015   64                 25  Victoria
#
#            department_name    job_title  store_name gender_short gender_full  \
# EmployeeID
# 1700                 Meats  Meat Cutter          37            M        Male
# 1700                 Meats  Meat Cutter          37            M        Male
# 1700                 Meats  Meat Cutter          37            M        Male
# 1700                 Meats  Meat Cutter          37            M        Male
# 1700                 Meats  Meat Cutter          37            M        Male
# 1700                 Meats  Meat Cutter          37            M        Male
# 1700                 Meats  Meat Cutter          37            M        Male
# 1700                 Meats  Meat Cutter          37            M        Male
# 1700                 Meats  Meat Cutter          37            M        Male
# 1700                 Meats  Meat Cutter          37            M        Male
#
#            termreason_desc   termtype_desc  STATUS_YEAR      STATUS  \
# EmployeeID
# 1700        Not Applicable  Not Applicable         2006      ACTIVE
# 1700        Not Applicable  Not Applicable         2007      ACTIVE
# 1700        Not Applicable  Not Applicable         2008      ACTIVE
# 1700        Not Applicable  Not Applicable         2009      ACTIVE
# 1700        Not Applicable  Not Applicable         2010      ACTIVE
# 1700        Not Applicable  Not Applicable         2011      ACTIVE
# 1700        Not Applicable  Not Applicable         2012      ACTIVE
# 1700        Not Applicable  Not Applicable         2013      ACTIVE
# 1700        Not Applicable  Not Applicable         2014      ACTIVE
# 1700                Layoff     Involuntary         2015  TERMINATED
#
#            BUSINESS_UNIT
# EmployeeID
# 1700              STORES
# 1700              STORES
# 1700              STORES
# 1700              STORES
# 1700              STORES
# 1700              STORES
# 1700              STORES
# 1700              STORES
# 1700              STORES
# 1700              STORES

# %%
df.loc[1800,['age']]
# Out:
#             age
# EmployeeID
# 1800         55
# 1800         56
# 1800         57
# 1800         58
# 1800         59
# 1800         60
# 1800         61
# 1800         62
# 1800         63
# 1800         64

# %%
df[(df['department_name'] == 'Meats') & (df['city_name'] == 'Kelowna')]
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1374        12/31/2006 0:00      4/6/1949       10/17/1989
# 1374        12/31/2007 0:00      4/6/1949       10/17/1989
# 1374        12/31/2008 0:00      4/6/1949       10/17/1989
# 1548        12/31/2006 0:00     2/23/1950         4/5/1990
# 1548        12/31/2007 0:00     2/23/1950         4/5/1990
# ...                     ...           ...              ...
# 2674          2/1/2007 0:00     2/11/1942        8/19/1993
# 2766         11/1/2008 0:00    12/23/1956       11/12/1993
# 2862          8/1/2007 0:00      8/7/1942        2/12/1994
# 2937         10/1/2007 0:00    10/25/1942         5/2/1994
# 3093          3/1/2008 0:00     3/20/1943        9/25/1994
#
#            terminationdate_key  age  length_of_service city_name  \
# EmployeeID
# 1374                  4/6/2009   57                 17   Kelowna
# 1374                  4/6/2009   58                 18   Kelowna
# 1374                  4/6/2009   59                 19   Kelowna
# 1548                 2/23/2015   56                 16   Kelowna
# 1548                 2/23/2015   57                 17   Kelowna
# ...                        ...  ...                ...       ...
# 2674                 2/11/2007   65                 13   Kelowna
# 2766                11/22/2008   51                 15   Kelowna
# 2862                  8/7/2007   65                 13   Kelowna
# 2937                10/25/2007   65                 13   Kelowna
# 3093                 3/20/2008   65                 13   Kelowna
#
#            department_name      job_title  store_name gender_short  \
# EmployeeID
# 1374                 Meats  Meats Manager          16            M
# 1374                 Meats  Meats Manager          16            M
# 1374                 Meats  Meats Manager          16            M
# 1548                 Meats    Meat Cutter          16            F
# 1548                 Meats    Meat Cutter          16            F
# ...                    ...            ...         ...          ...
# 2674                 Meats    Meat Cutter          16            F
# 2766                 Meats    Meat Cutter          16            F
# 2862                 Meats    Meat Cutter          16            F
# 2937                 Meats    Meat Cutter          16            F
# 3093                 Meats    Meat Cutter          16            F
#
#            gender_full termreason_desc   termtype_desc  STATUS_YEAR  \
# EmployeeID
# 1374              Male  Not Applicable  Not Applicable         2006
# 1374              Male  Not Applicable  Not Applicable         2007
# 1374              Male  Not Applicable  Not Applicable         2008
# 1548            Female  Not Applicable  Not Applicable         2006
# 1548            Female  Not Applicable  Not Applicable         2007
# ...                ...             ...             ...          ...
# 2674            Female      Retirement       Voluntary         2007
# 2766            Female      Resignaton       Voluntary         2008
# 2862            Female      Retirement       Voluntary         2007
# 2937            Female      Retirement       Voluntary         2007
# 3093            Female      Retirement       Voluntary         2008
#
#                 STATUS BUSINESS_UNIT
# EmployeeID
# 1374            ACTIVE        STORES
# 1374            ACTIVE        STORES
# 1374            ACTIVE        STORES
# 1548            ACTIVE        STORES
# 1548            ACTIVE        STORES
# ...                ...           ...
# 2674        TERMINATED        STORES
# 2766        TERMINATED        STORES
# 2862        TERMINATED        STORES
# 2937        TERMINATED        STORES
# 3093        TERMINATED        STORES
#
# [674 rows x 17 columns]

# %%
df.department_name.value_counts()
# Out:
# department_name
# Meats                     10269
# Dairy                      8599
# Produce                    8515
# Bakery                     8381
# Customer Service           7122
# Processed Foods            5911
# Store Management            271
# Executive                   100
# Recruitment                  72
# HR Technology                64
# Accounting                   59
# Employee Records             44
# Accounts Receiveable         39
# Labor Relations              34
# Accounts Payable             34
# Training                     30
# Compensation                 24
# Audit                        24
# Investment                   24
# Information Technology       20
# Legal                        17
# Name: count, dtype: int64

# %% [markdown]
# #### 3.B Sort the dataframe using the index

# %%
df.sort_index()
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# 1                1/1/1900   53                 18    Vancouver
# 2                1/1/1900   54                 19    Vancouver
# 3                1/1/1900   55                 20    Vancouver
# 4                1/1/1900   56                 21    Vancouver
# ...                   ...  ...                ...          ...
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 0             Executive           CEO          35            M        Male
# 1             Executive           CEO          35            M        Male
# 2             Executive           CEO          35            M        Male
# 3             Executive           CEO          35            M        Male
# 4             Executive           CEO          35            M        Male
# ...                 ...           ...         ...          ...         ...
# 49648             Dairy  Dairy Person          34            M        Male
# 49649  Customer Service       Cashier          44            F      Female
# 49650  Customer Service       Cashier          39            F      Female
# 49651  Customer Service       Cashier          16            F      Female
# 49652  Customer Service       Cashier          13            F      Female
#
#       termreason_desc   termtype_desc  STATUS_YEAR      STATUS BUSINESS_UNIT
# 0      Not Applicable  Not Applicable         2006      ACTIVE    HEADOFFICE
# 1      Not Applicable  Not Applicable         2007      ACTIVE    HEADOFFICE
# 2      Not Applicable  Not Applicable         2008      ACTIVE    HEADOFFICE
# 3      Not Applicable  Not Applicable         2009      ACTIVE    HEADOFFICE
# 4      Not Applicable  Not Applicable         2010      ACTIVE    HEADOFFICE
# ...               ...             ...          ...         ...           ...
# 49648          Layoff     Involuntary         2015  TERMINATED        STORES
# 49649      Resignaton       Voluntary         2013  TERMINATED        STORES
# 49650          Layoff     Involuntary         2015  TERMINATED        STORES
# 49651      Resignaton       Voluntary         2013  TERMINATED        STORES
# 49652          Layoff     Involuntary         2014  TERMINATED        STORES
#
# [49653 rows x 18 columns]

# %%
df.sort_index(ascending= False)
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 8336        12/31/2015 0:00    12/31/1994       12/11/2013
# 8336        12/31/2014 0:00    12/31/1994       12/11/2013
# 8336        12/31/2013 0:00    12/31/1994       12/11/2013
# 8335        12/31/2015 0:00    12/28/1994       12/10/2013
# 8335        12/31/2014 0:00    12/28/1994       12/10/2013
# ...                     ...           ...              ...
# 1318        12/31/2011 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 8336                  1/1/1900   21                  2  Vancouver
# 8336                  1/1/1900   20                  1  Vancouver
# 8336                  1/1/1900   19                  0  Vancouver
# 8335                  1/1/1900   21                  2  Vancouver
# 8335                  1/1/1900   20                  1  Vancouver
# ...                        ...  ...                ...        ...
# 1318                  1/1/1900   57                 22  Vancouver
# 1318                  1/1/1900   56                 21  Vancouver
# 1318                  1/1/1900   55                 20  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# 1318                  1/1/1900   52                 17  Vancouver
#
#            department_name     job_title  store_name gender_short gender_full  \
# EmployeeID
# 8336                 Dairy  Dairy Person          35            M        Male
# 8336                 Dairy  Dairy Person          35            M        Male
# 8336                 Dairy  Dairy Person          35            M        Male
# 8335                 Dairy  Dairy Person          35            F      Female
# 8335                 Dairy  Dairy Person          35            F      Female
# ...                    ...           ...         ...          ...         ...
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
# 1318             Executive           CEO          35            M        Male
#
#            termreason_desc   termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# EmployeeID
# 8336        Not Applicable  Not Applicable         2015  ACTIVE        STORES
# 8336        Not Applicable  Not Applicable         2014  ACTIVE        STORES
# 8336        Not Applicable  Not Applicable         2013  ACTIVE        STORES
# 8335        Not Applicable  Not Applicable         2015  ACTIVE        STORES
# 8335        Not Applicable  Not Applicable         2014  ACTIVE        STORES
# ...                    ...             ...          ...     ...           ...
# 1318        Not Applicable  Not Applicable         2011  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2010  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2009  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2008  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2006  ACTIVE    HEADOFFICE
#
# [49653 rows x 17 columns]

# %%
df['length_of_service'].sort_values()
# Out:
# 46639     0
# 46658     0
# 40391     0
# 46654     0
# 40400     0
#          ..
# 69       26
# 89       26
# 39       26
# 49       26
# 9        26
# Name: length_of_service, Length: 49653, dtype: int64

# %%
df.sort_values('length_of_service',ascending = False)
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 
#
#              department_name      job_title  store_name gender_short  \
# EmployeeID
# 3176                   Meats    Meat Cutter          29            F
# 7581        Customer Service        Cashier          32            M
# 6415         Processed Foods  Shelf Stocker          43            M
# 4367                 Produce  Produce Clerk          16            M
# 6719        Customer Service        Cashier          43            M
# 5847                  Bakery          Baker           8            F
# 5545                  Bakery          Baker          15            F
# 4275                 Produce  Produce Clerk          21            F
# 5074                  Bakery          Baker          18            F
# 4946                 Produce  Produce Clerk           2            M
# 5138                   Meats    Meat Cutter          46            M
# 7075                   Dairy   Dairy Person           5            F
# 1404                Training        Trainer          35            F
# 6489                  Bakery          Baker           2            F
# 5126                  Bakery          Baker          18            M
#
#            gender_full termreason_desc   termtype_desc  STATUS_YEAR  STATUS  \
# EmployeeID
# 3176            Female  Not Applicable  Not Applicable         2011  ACTIVE
# 7581              Male  Not Applicable  Not Applicable         2010  ACTIVE
# 6415              Male  Not Applicable  Not Applicable         2015  ACTIVE
# 4367              Male  Not Applicable  Not Applicable         2008  ACTIVE
# 6719              Male  Not Applicable  Not Applicable         2014  ACTIVE
# 5847            Female  Not Applicable  Not Applicable         2010  ACTIVE
# 5545            Female  Not Applicable  Not Applicable         2015  ACTIVE
# 4275            Female  Not Applicable  Not Applicable         2009  ACTIVE
# 5074            Female  Not Applicable  Not Applicable         2011  ACTIVE
# 4946              Male  Not Applicable  Not Applicable         2011  ACTIVE
# 5138              Male  Not Applicable  Not Applicable         2012  ACTIVE
# 7075            Female  Not Applicable  Not Applicable         2013  ACTIVE
# 1404            Female  Not Applicable  Not Applicable         2013  ACTIVE
# 6489            Female  Not Applicable  Not Applicable         2009  ACTIVE
# 5126              Male  Not Applicable  Not Applicable         2008  ACTIVE
#
#            BUSINESS_UNIT
# EmployeeID
# 3176              STORES
# 7581              STORES
# 6415              STORES
# 4367              STORES
# 6719              STORES
# 5847              STORES
# 5545              STORES
# 4275              STORES
# 5074              STORES
# 4946              STORES
# 5138              STORES
# 7075              STORES
# 1404          HEADOFFICE
# 6489              STORES
# 5126              STORES

# %% [markdown]
# # 4. Query Data Frame
#
# #### 4.A Find rows Where `job_title` is CEO

# %%
df[df['job_title'] == 'CEO']
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# 1318        12/31/2011 0:00      1/3/1954        8/28/1989
# 1318        12/31/2012 0:00      1/3/1954        8/28/1989
# 1318        12/31/2013 0:00      1/3/1954        8/28/1989
# 1318        12/31/2014 0:00      1/3/1954        8/28/1989
# 1318        12/31/2015 0:00      1/3/1954        8/28/1989
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# 1318                  1/1/1900   55                 20  Vancouver
# 1318                  1/1/1900   56                 21  Vancouver
# 1318                  1/1/1900   57                 22  Vancouver
# 1318                  1/1/1900   58                 23  Vancouver
# 1318                  1/1/1900   59                 24  Vancouver
# 1318                  1/1/1900   60                 25  Vancouver
# 1318                  1/1/1900   61                 26  Vancouver
#
#            department_name job_title  store_name gender_short gender_full  \
# EmployeeID
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
# 1318             Executive       CEO          35            M        Male
#
#            termreason_desc   termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# EmployeeID
# 1318        Not Applicable  Not Applicable         2006  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2007  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2008  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2009  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2010  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2011  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2012  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2013  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2014  ACTIVE    HEADOFFICE
# 1318        Not Applicable  Not Applicable         2015  ACTIVE    HEADOFFICE

# %%
df['job_title'] == 'CEO'
# boolean data type
# Out:
# EmployeeID
# 1318     True
# 1318     True
# 1318     True
# 1318     True
# 1318     True
#         ...
# 8258    False
# 8264    False
# 8279    False
# 8296    False
# 8321    False
# Name: job_title, Length: 49653, dtype: bool

# %%
df[(df['length_of_service']==17) & (df['city_name']== 'Vancouver') ]['age'].min()
# Out:
# 42

# %%
df[(df.length_of_service>10) & (df.age<50)]
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1319        12/31/2006 0:00      1/3/1957        8/28/1989
# 1321        12/31/2006 0:00      1/2/1959        8/28/1989
# 1321        12/31/2007 0:00      1/2/1959        8/28/1989
# 1321        12/31/2008 0:00      1/2/1959        8/28/1989
# 1322        12/31/2006 0:00      1/9/1958        8/31/1989
# ...                     ...           ...              ...
# 5882         12/1/2014 0:00    11/28/1975       11/12/2003
# 5920         12/1/2015 0:00      3/7/1976         1/3/2004
# 5951         12/1/2015 0:00     6/11/1976        2/23/2004
# 5959         12/1/2015 0:00     7/13/1976        3/11/2004
# 6111         12/1/2015 0:00    11/10/1977       11/22/2004
#
#            terminationdate_key  age  length_of_service    city_name  \
# EmployeeID
# 1319                  1/1/1900   49                 17    Vancouver
# 1321                  1/1/1900   47                 17    Vancouver
# 1321                  1/1/1900   48                 18    Vancouver
# 1321                  1/1/1900   49                 19    Vancouver
# 1322                  1/1/1900   48                 17    Vancouver
# ...                        ...  ...                ...          ...
# 5882                12/30/2014   39                 11  Grand Forks
# 5920                12/30/2015   39                 11   White Rock
# 5951                12/30/2015   39                 11    Princeton
# 5959                12/30/2015   39                 11   White Rock
# 6111                12/30/2015   38                 11    Princeton
#
#              department_name           job_title  store_name gender_short  \
# EmployeeID
# 1319               Executive           VP Stores          35            F
# 1321               Executive  VP Human Resources          35            M
# 1321               Executive  VP Human Resources          35            M
# 1321               Executive  VP Human Resources          35            M
# 1322               Executive          VP Finance          35            M
# ...                      ...                 ...         ...          ...
# 5882                 Produce       Produce Clerk          13            F
# 5920        Customer Service             Cashier          39            M
# 5951         Processed Foods       Shelf Stocker          27            F
# 5959        Customer Service             Cashier          39            F
# 6111                  Bakery               Baker          27            M
#
#            gender_full termreason_desc   termtype_desc  STATUS_YEAR  \
# EmployeeID
# 1319            Female  Not Applicable  Not Applicable         2006
# 1321              Male  Not Applicable  Not Applicable         2006
# 1321              Male  Not Applicable  Not Applicable         2007
# 1321              Male  Not Applicable  Not Applicable         2008
# 1322              Male  Not Applicable  Not Applicable         2006
# ...                ...             ...             ...          ...
# 5882            Female          Layoff     Involuntary         2014
# 5920              Male          Layoff     Involuntary         2015
# 5951            Female          Layoff     Involuntary         2015
# 5959            Female          Layoff     Involuntary         2015
# 6111              Male          Layoff     Involuntary         2015
#
#                 STATUS BUSINESS_UNIT
# EmployeeID
# 1319            ACTIVE    HEADOFFICE
# 1321            ACTIVE    HEADOFFICE
# 1321            ACTIVE    HEADOFFICE
# 1321            ACTIVE    HEADOFFICE
# 1322            ACTIVE    HEADOFFICE
# ...                ...           ...
# 5882        TERMINATED        STORES
# 5920        TERMINATED        STORES
# 5951        TERMINATED        STORES
# 5959        TERMINATED        STORES
# 6111        TERMINATED        STORES
#
# [9306 rows x 17 columns]

# %% [markdown]
# #### 4.B Group by `age` and find how many there are of each age

# %%
df.groupby('city_name', as_index = False).age.mean().sort_values(by = 'age',ascending = False)
# Out:
#            city_name        age
# 22       Ocean Falls  51.307692
# 9         Dease Lake  46.000000
# 24    Port Coquitlam  44.511927
# 8       Dawson Creek  43.961240
# 37    West Vancouver  43.949429
# 31           Terrace  43.708469
# 29          Squamish  43.440447
# 16           Langley  43.355161
# 35            Vernon  42.983296
# 27           Quesnel  42.960171
# 30            Surrey  42.903205
# 5         Chilliwack  42.774636
# 36          Victoria  42.699898
# 15           Kelowna  42.573816
# 34         Vancouver  42.416466
# 38        White Rock  41.891775
# 32             Trail  41.887568
# 4            Burnaby  41.804548
# 17           Nanaimo  41.743034
# 1         Aldergrove  41.592308
# 39     Williams Lake  41.568882
# 11      Fort St John  41.534622
# 21   North Vancouver  41.498457
# 6      Cortes Island  41.488372
# 25     Prince George  41.379395
# 20   New Westminster  41.300218
# 7          Cranbrook  41.109244
# 14          Kamloops  41.092673
# 28          Richmond  40.820842
# 0         Abbotsford  40.728341
# 18            Nelson  40.037855
# 3         Blue River  40.000000
# 23      Pitt Meadows  39.824561
# 13             Haney  39.802198
# 19  New Westminister  39.074803
# 10       Fort Nelson  38.894410
# 2        Bella Bella  37.769841
# 26         Princeton  37.500000
# 12       Grand Forks  37.343220
# 33         Valemount  34.972973

# %%
df.groupby(['age']).size()
# Out:
# age
# 19     158
# 20     408
# 21     703
# 22     815
# 23     960
# 24    1111
# 25    1197
# 26    1210
# 27    1235
# 28    1225
# 29    1227
# 30    1212
# 31    1146
# 32    1153
# 33    1164
# 34    1188
# 35    1189
# 36    1176
# 37    1149
# 38    1156
# 39    1142
# 40    1130
# 41    1135
# 42    1152
# 43    1150
# 44    1157
# 45    1141
# 46    1161
# 47    1173
# 48    1180
# 49    1196
# 50    1218
# 51    1207
# 52    1188
# 53    1188
# 54    1159
# 55    1168
# 56    1154
# 57    1130
# 58    1130
# 59    1128
# 60    1109
# 61     757
# 62     712
# 63     667
# 64     646
# 65     593
# dtype: int64

# %% [markdown]
# # 5. Visualisation
#
#
# #### 5.A Plot a histogram of `age`

# %%
plt.hist(df['age'],bins= 20, facecolor='blue', alpha=0.5)
# Out:
# (array([1269., 1775., 2308., 3670., 2439., 2299., 3541., 2325., 2298.,
#         2265., 3459., 2302., 2353., 3621., 2376., 2327., 3414., 2237.,
#         1469., 1906.]),
#  array([19. , 21.3, 23.6, 25.9, 28.2, 30.5, 32.8, 35.1, 37.4, 39.7, 42. ,
#         44.3, 46.6, 48.9, 51.2, 53.5, 55.8, 58.1, 60.4, 62.7, 65. ]),
#  <BarContainer object of 20 artists>)

# %%
n, bins ,patches = plt.hist(df.age,bins= 25, facecolor='blue', alpha=0.5)

# %% [markdown]
# #### 5.B BoxPlot of `age`

# %%
plt.boxplot(df.age)
plt.show()

# %% [markdown]
# #### 5.C Create a scatterplot of `age` and `length_of_service`

# %%
plt.scatter(df.age,df.length_of_service)
plt.show()

# %% [markdown]
# #### 5.D Print a statistical summary of `age`

# %%
print('satistical summary of observation : /n ',stats.describe(df.age))
# Out:
# satistical summary of observation : /n  DescribeResult(nobs=49653, minmax=(19, 65), mean=42.077034620264634, variance=154.43672646776537, skewness=0.023093117697645202, kurtosis=-1.1473302603578608)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
